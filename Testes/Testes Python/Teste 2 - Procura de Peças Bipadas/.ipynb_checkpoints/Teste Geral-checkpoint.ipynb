# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('input/coletaComFinal.txt', delimiter = ' ')
df
# Out:
#                  Peças
# 0     1000972458101201
# 1     1000972457101202
# 2     1000972456101203
# 3     1000972459101204
# 4     1000972460101205
# ..                 ...
# 178   1000192665536105
# 179   1000902827538101
# 180   1000913714538102
# 181   1000903815538103
# 182  10008924314539201
#
# [183 rows x 1 columns]

# %%
df.insert(1, "Local", ['' for i in range(0, len(df.index))], allow_duplicates = True)
df
# Out:
#                  Peças Local
# 0     1000972458101201
# 1     1000972457101202
# 2     1000972456101203
# 3     1000972459101204
# 4     1000972460101205
# ..                 ...   ...
# 178   1000192665536105
# 179   1000902827538101
# 180   1000913714538102
# 181   1000903815538103
# 182  10008924314539201
#
# [183 rows x 2 columns]

# %%
df["Local"] = df["Peças"].map(lambda x: int(str(x)[-6:]))
df["Peças"] = df["Peças"].map(lambda x: int(str(x)[:-6]))
df
# Out:
#            Peças   Local
# 0     1000972458  101201
# 1     1000972457  101202
# 2     1000972456  101203
# 3     1000972459  101204
# 4     1000972460  101205
# ..           ...     ...
# 178   1000192665  536105
# 179   1000902827  538101
# 180   1000913714  538102
# 181   1000903815  538103
# 182  10008924314  539201
#
# [183 rows x 2 columns]

# %%
def defineRua(string):
    
    if string == '1':
        return 'A'
    elif string == '2':
        return 'B'
    elif string == '3':
        return 'C'
    elif string == '4':
        return 'D'
    elif string == '5':
        return 'E'
    else:
        return "ERRO"

def defineColunaEGaveta(n):
    
    col = str(n // 10)
    gav = str(n % 10)
    
    if(len(str(gav)) == 1):
        return " G{} C0{}".format(col, gav)
    else:
        return " G{} C{}".format(col, gav)


def transformaLocal(df, coluna):
    
    df[coluna] = df[coluna].map(lambda x: "R" + defineRua(str(x)[0]) + defineColunaEGaveta(int(str(x)[1:4])))

# %%
transformaLocal(df, "Local")
df.columns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-6902c6c9123a> in <module>
# ----> 1 transformaLocal(df, "Local")
#       2 df.columns
#
# <ipython-input-5-ea179d630f8e> in transformaLocal(df, coluna)
#      27 def transformaLocal(df, coluna):
#      28
# ---> 29     df[coluna] = df[coluna].map(lambda x: "R" + defineRua(str(x)[0]) + defineColunaEGaveta(int(str(x)[1:4])))
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in map(self, arg, na_action)
#    3907         dtype: object
#    3908         """
# -> 3909         new_values = super()._map_values(arg, na_action=na_action)
#    3910         return self._constructor(new_values, index=self.index).__finalize__(
#    3911             self, method="map"
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in _map_values(self, mapper, na_action)
#     935
#     936         # mapper is a function
# --> 937         new_values = map_f(values, mapper)
#     938
#     939         return new_values
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-5-ea179d630f8e> in <lambda>(x)
#      27 def transformaLocal(df, coluna):
#      28
# ---> 29     df[coluna] = df[coluna].map(lambda x: "R" + defineRua(str(x)[0]) + defineColunaEGaveta(int(str(x)[1:4])))
#
# ValueError: invalid literal for int() with base 10: 'A G'

# %%
df[df["Local"].str.len() != 3]

# %%
a = 2.0
b = a.2f
b
# Out:
#   File "<ipython-input-10-3aad86bf5f04>", line 2
#     b = a.2f
#          ^
# SyntaxError: invalid syntax
